# %% [markdown]
# # Tasks
#
# - In your own words, write a short paragraph: “What is Machine Learning and why does it matter?”
#
#     Machine Learning is part of a bigger field called Artificial Intelligence. It uses math, data, and programming to make a machine learn to do something through training and generalize its solutions.
#
# - Look for three real-world ML applications that you find interesting or surprising.
#     - Learning and simulating physics principles with ML.
#     - Applying ML tools to enhance education.
#     - Implementing ML in public health for medical purposes.

# %% [markdown]
# # Code example
# **This just loads a classic dataset and visualizes relationships. No ML training yet, but it's a taste of what’s coming**
#
# ```mermaid
# graph LR
#     A[Load basic tools] --> B[Load a basic toy dataset from sklearn]
#     B --> C[ Preview]
#     C --> D[Simple visualization]
# ```

# %%
# Load basic tools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# # Load toy dataset from sklearn
from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names) 
df["target"] = iris.target

# Preview
print("First rows of the dataset:")
print(df.head())

# Simple visualization
sns.pairplot(df, hue="target")
plt.suptitle("Iris Dataset Visualization", y=1.02)
plt.show()
# Out:
# First rows of the dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
